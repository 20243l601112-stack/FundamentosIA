# %%
# Preposiciones
P: El servidor principal esta disponible
Q: Latencia supera el limite establecido
R: Perdida de paquete supera el limite permitido
T: trafico de red anormalmente alto
S: Servidor de respaldo esta disponible
M: Sistema de monitoreo este activo
