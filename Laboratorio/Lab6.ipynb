# %%
### LAB06

# %%
#Libreria utilizada para graficar
import matplotlib.pyplot as plt

import networkx as nx

# %%
#creamos una instancia de la clase  graph
#Graph  es una coleccion de nodos
grafo = nx.Graph()

# %%
grafo.add_edges_from(
    [
        ("A","B"),
        ("B","D"),
        ("D","F"),
        ("F","H"),
        ("H","I"),
        ("I","J"),
        ("A","C"),
        ("C","G"),
        ("G","E"),
        ("E","F"),
        ("G","J")
    ]
)

# %%
nx.draw(
    grafo,
    with_labels = True,
    node_size=1000
)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Mostrar las rutas posibles del grafo
rutas= list (
    nx.all_simple_paths(grafo, source="A", target="J")
)

# %%
#imprimir las rutas
print("Rutas encontradas:")
for i, ruta in enumerate(rutas, start=1):
    print(f"Ruta {i}: {ruta}")
# Out:
# Rutas encontradas:
# Ruta 1: ['A', 'B', 'D', 'F', 'H', 'I', 'J']
# Ruta 2: ['A', 'B', 'D', 'F', 'E', 'G', 'J']
# Ruta 3: ['A', 'C', 'G', 'E', 'F', 'H', 'I', 'J']
# Ruta 4: ['A', 'C', 'G', 'J']

# %%
#Mostrar el total de pasos de cada ruta
pasos1 = len (rutas[0])-1
print("Pasos de la ruta 1: ", pasos1)
pasos2 = len(rutas[1])-1
print("Pasos de la ruta 2: ", pasos2)
pasos3 = len(rutas[2])-1
print("Pasos de la ruta 3: ", pasos3)
pasos4 = len(rutas[3])-1
print("Pasos de la ruta 4: ", pasos4)
# Out:
# Pasos de la ruta 1:  6
# Pasos de la ruta 2:  6
# Pasos de la ruta 3:  7
# Pasos de la ruta 4:  3

# %%
# Aplicamos la logica proposicional
P = pasos1 < pasos2 and pasos1 < pasos3 and pasos1 < pasos4
Q = pasos2 < pasos1 and pasos2 < pasos3 and pasos2 < pasos4
R = pasos3 < pasos1 and pasos3 < pasos2 and pasos3 < pasos4
S = pasos4 < pasos1 and pasos4 < pasos2 and pasos4 < pasos3


if P==True:
    print("P = True")
    print("La ruta 1 es mejor opcion.")
elif Q==True:
    print("Q = True")
    print("La ruta 2 es mejor opcion.")
elif R==True:
    print("R = True")
    print("La ruta 3 es mejor opcion")
elif S==True:
    print("S = True")
    print("La ruta 4 es mejor opcion")
else:
    print("P = False")
    print("Q = False")
    print("R = False")
    print("S = False")
    print("Las cuatro rutas son iguales de buenas, haz lo que quieras!")
# Out:
# S = True
# La ruta 4 es mejor opcion

# %%
grafo.add_edges_from(
    [
        ("A","B"),
        ("B","D"),
        ("D","F"),
        ("F","H"),
        ("H","I"),
        ("I","J"),
        ("A","C"),
        ("C","G"),
        ("G","E"),
        ("E","F"),
        ("G","J")
    ]
)

# %%
grafo.remove_edge("G","J")

# %%
nx.draw(
    grafo,
    with_labels = True,
    node_size=1000
)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Mostrar las rutas posibles del grafo
rutas= list (
    nx.all_simple_paths(grafo, source="A", target="J")
)

# %%
#imprimir las rutas
print("Rutas encontradas:")
for i, ruta in enumerate(rutas, start=1):
    print(f"Ruta {i}: {ruta}")
# Out:
# Rutas encontradas:
# Ruta 1: ['A', 'B', 'D', 'F', 'H', 'I', 'J']
# Ruta 2: ['A', 'C', 'G', 'E', 'F', 'H', 'I', 'J']

# %%
#Mostrar el total de pasos de cada ruta
pasos1 = len (rutas[0])-1
print("Pasos de la ruta 1: ", pasos1)
pasos2 = len(rutas[1])-1
print("Pasos de la ruta 2: ", pasos2)
# Out:
# Pasos de la ruta 1:  6
# Pasos de la ruta 2:  7

# %%
# Aplicamos la logica proposicional
P = pasos1 < pasos2 
Q = pasos2 < pasos1

# %%
if P==True:
    print("P = True")
    print("La ruta 1 es mejor opcion.")
elif Q==True:
    print("Q = True")
    print("La ruta 2 es mejor opcion.")
else:
    print("Las rutas son iguales de buenas, haz lo que quieras!")
# Out:
# P = True
# La ruta 1 es mejor opcion.
